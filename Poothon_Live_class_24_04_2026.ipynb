# %% [markdown]
# <a href="https://colab.research.google.com/github/vishrutxraj/JIOIN-Python-pre-term-course/blob/main/Poothon_Live_class_24_04_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI AGENTS
# https://academy.langchain.com/courses/intro-to-langgraph
#
# AG-UI, A2A, Consider claude Team (Pro), explore decorator(in python)

# %%
def greet_user(name: str):
  print(f"hello {name}, have a great day")



if __name__ == "__main__":
  username = input("Hey, What is your name? ")
  greet_user(username)
# Out:
# Hey, What is your name? Mallludon
# hello Mallludon, have a great day

# %% [markdown]
# #API
#
# *  GET - Read Data
# *  POST - Write Data
# *  PUT/PATCH - Update Data
# *  DELETE - Delete Data

# %% [markdown]
# #API STATUS CODES
# https://www.w3schools.com/tags/ref_httpmessages.asp
# ;; https://developer.mozilla.org/en-US/docs/Web/HTTP/Reference/Status

# %% [markdown]
# #HW
# Use FastAPI to build a basic Crud Application. Using the operations taught in class.
